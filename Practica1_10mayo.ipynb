# %%
from  pylab import plot, show
y=[1., 2., 4., 0.3, 5.2]
plot( y )
show()

# %%
x=[0.5, 1., 2., 4., 7., 10.]
y=[1., 2., 4., 0.3, 5.2, 6.6]
plot(x,y)
show()

# %%
from pylab import savefig
plot(x,y)
savefig('figura1:YvsX.eps', format='ps', dpi=1000)
show()

# %%
from numpy import linspace, sin, cos
x=linspace(0, 10, 1000)
y=sin(x)
plot(x,y)
show()
from pylab import savefig
plot(x,y)
savefig('figura2:Y=sin(x)', format='eps', dpi=1000)
show()

# %%
from numpy import linspace, sin, cos, tan
from pylab import ylim, xlim, grid, xlabel, ylabel
x=linspace(0, 10, 100)
y=tan(x)
#plot(x,y)
#plot(x,y,'g--')
plot(x,y,'bo')
ylim(-1.1, 1.1)
xlim(0., 10)
grid("on")
savefig('figura3:Y=tan(x)', format='eps', dpi=1000)
xlabel("eje X")
ylabel("eje Y")
show()

# %%
from numpy import linspace, sin, cos, tan
from pylab import ylim, xlim, grid, xlabel, ylabel
x=linspace(0, 10, 1000)
y=sin(x)
#plot(x,y)
#plot(x,y,'g--')
plot(x,y,'k-')
y=cos(x)
plot(x,y,'k--')
ylim(-1.1, 1.1)
xlim(0., 10)
grid("on")
savefig('figura3:Y=tan(x)', format='eps', dpi=1000)
xlabel("eje X")
ylabel("eje Y")
show()

# %%
from numpy import loadtxt
dataCO2 = loadtxt("co2_mm_gl.txt", float)
plot(dataCO2[:,0], dataCO2[:,1])
show()

# %%
from numpy import  loadtxt
from pylab import  xlim, ylim, grid, savefig, xlabel, ylabel, show
dataCO2 = loadtxt("co2_mm_gl.txt", float)
plot(dataCO2[:,2], dataCO2[:,3])
plot(dataCO2[:,2], dataCO2[:,4])
#show()
#plot(x,y,'k--')
#ylim(-1.1, 1.1)
#xlim(0., 10)
grid("on")
savefig('figura4:Avarge)', format='eps', dpi=1000)
xlabel("Year")
ylabel("Parts Per Million")
show()

# %%
los estandares de desvición en los niveles de contaminación de co2 se han ido incrementando con el transcurrir del tiempo
